# %%
langcode_map = {
    "ace_Latn": "Acehnese",
    "afr_Latn": "Afrikaans",
    "als_Latn": "Tosk Albanian",
    "arb_Latn": "Modern Standard Arabic",
    "arg_Latn": "Aragonese",
    "ast_Latn": "Asturian",
    "ayr_Latn": "Central Aymara",
    "azj_Latn": "North Azerbaijani",
    "bam_Latn": "Bambara",
    "ban_Latn": "Balinese",
    "bem_Latn": "Bemba",
    "bjn_Latn": "Banjar",
    "bos_Latn": "Bosnian",
    "bug_Latn": "Buginese",
    "cat_Latn": "Catalan",
    "ceb_Latn": "Cebuano",
    "ces_Latn": "Czech",
    "cjk_Latn": "Chokwe",
    "crh_Latn": "Crimean Tatar",
    "cym_Latn": "Welsh",
    "dan_Latn": "Danish",
    "deu_Latn": "German",
    "dik_Latn": "Southwestern Dinka",
    "dyu_Latn": "Dyula",
    "ekk_Latn": "Estonian",
    "eng_Latn": "English",
    "epo_Latn": "Esperanto",
    "eus_Latn": "Basque",
    "ewe_Latn": "Ewe",
    "fao_Latn": "Faroese",
    "fij_Latn": "Fijian",
    "fil_Latn": "Filipino",
    "fin_Latn": "Finnish",
    "fon_Latn": "Fon",
    "fra_Latn": "French",
    "fur_Latn": "Friulian",
    "fuv_Latn": "Nigerian Fulfulde",
    "gaz_Latn": "West Central Oromo",
    "gla_Latn": "Scottish Gaelic",
    "gle_Latn": "Irish",
    "glg_Latn": "Galician",
    "gug_Latn": "Paraguayan Guaraní",
    "hat_Latn": "Haitian Creole",
    "hau_Latn": "Hausa",
    "hrv_Latn": "Croatian",
    "hun_Latn": "Hungarian",
    "ibo_Latn": "Igbo",
    "ilo_Latn": "Iloko",
    "ind_Latn": "Indonesian",
    "isl_Latn": "Icelandic",
    "ita_Latn": "Italian",
    "jav_Latn": "Javanese",
    "kaa_Latn": "Karakalpak",
    "kab_Latn": "Kabyle",
    "kac_Latn": "Jinghpaw",
    "kam_Latn": "Kamba",
    "kbp_Latn": "Kabiyè",
    "kea_Latn": "Kabuverdianu",
    "kik_Latn": "Kikuyu",
    "kin_Latn": "Kinyarwanda",
    "kmb_Latn": "Kimbundu",
    "kmr_Latn": "Northern Kurdish",
    "knc_Latn": "Central Kanuri",
    "ktu_Latn": "Kituba",
    "lij_Latn": "Ligurian",
    "lim_Latn": "Limburgish",
    "lin_Latn": "Lingala",
    "lit_Latn": "Lithuanian",
    "lld_Latn": "Ladin",
    "lmo_Latn": "Lombard",
    "ltg_Latn": "Latgalian",
    "ltz_Latn": "Luxembourgish",
    "lua_Latn": "Luba-Kasai",
    "lug_Latn": "Ganda",
    "luo_Latn": "Luo",
    "lus_Latn": "Mizo",
    "lvs_Latn": "Latvian",
    "min_Latn": "Minangkabau",
    "mlt_Latn": "Maltese",
    "mos_Latn": "Mossi",
    "mri_Latn": "Māori",
    "nld_Latn": "Dutch",
    "nno_Latn": "Norwegian Nynorsk",
    "nob_Latn": "Norwegian Bokmål",
    "nso_Latn": "Northern Sotho",
    "nus_Latn": "Nuer",
    "nya_Latn": "Nyanja",
    "oci_Latn": "Occitan",
    "oci_Latn_aran1260": "Aranese",
    "pag_Latn": "Pangasinan",
    "pap_Latn": "Papiamento",
    "plt_Latn": "Plateau Malagasy",
    "pol_Latn": "Polish",
    "por_Latn": "Portuguese",
    "quy_Latn": "Ayacucho Quechua",
    "ron_Latn": "Romanian",
    "run_Latn": "Rundi",
    "sag_Latn": "Sango",
    "scn_Latn": "Sicilian",
    "slk_Latn": "Slovak",
    "slv_Latn": "Slovenian",
    "smo_Latn": "Samoan",
    "sna_Latn": "Shona",
    "som_Latn": "Somali",
    "sot_Latn": "Southern Sotho",
    "spa_Latn": "Spanish",
    "srd_Latn": "Sardinian",
    "ssw_Latn": "Swati",
    "sun_Latn": "Sundanese",
    "swe_Latn": "Swedish",
    "swh_Latn": "Swahili",
    "szl_Latn": "Silesian",
    "taq_Latn": "Tamasheq",
    "tpi_Latn": "Tok Pisin",
    "tsn_Latn": "Tswana",
    "tso_Latn": "Tsonga",
    "tuk_Latn": "Turkmen",
    "tum_Latn": "Tumbuka",
    "tur_Latn": "Turkish",
    "twi_Latn_akua1239": "Akuapem Twi",
    "twi_Latn_asan1239": "Asante Twi",
    "umb_Latn": "Umbundu",
    "uzn_Latn": "Northern Uzbek",
    "vec_Latn": "Venetian",
    "vie_Latn": "Vietnamese",
    "vmw_Latn": "Emakhuwa",
    "war_Latn": "Waray",
    "wol_Latn": "Wolof",
    "xho_Latn": "Xhosa",
    "yor_Latn": "Yoruba",
    "zsm_Latn": "Standard Malay",
    "zul_Latn": "Zulu",
}

# %%
import json

with open("eval_dummy.json") as f:
    data2 = json.load(f)

# %%
import numpy as np

avg_bleu = np.mean([data2[lang]["bleu"] for lang in data2.keys()])
avg_bleu
# Out:
# np.float64(0.29091532889862376)

# %%
import matplotlib.pyplot as plt

bleu_scores_data2 = [data2[lang]['bleu'] for lang in list(data2.keys())]

avg = np.mean(bleu_scores_data2)

plt.figure(figsize=(17, 5))
plt.bar(languages, bleu_scores_data2, label='BLEU', alpha=0.7)
plt.margins(x=0.01)

plt.xlabel('Languages')
plt.ylabel('BLEU Scores')
plt.title('BLEU Scores by Language')
plt.axhline(y=avg, color='r', linestyle='--', label='Average BLEU')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
plt.show()

# %%
chrf_scores = [data2[lang]['chrf'] for lang in list(data2.keys())]

plt.figure(figsize=(17, 5))
plt.bar(languages, chrf_scores, label='ChrF++', alpha=0.7, color='orange')
plt.margins(x=0.01)

avg = np.mean(chrf_scores)

plt.xlabel('Languages')
plt.ylabel('ChrF++ Scores')
plt.ylim(0, 10)
plt.title('ChrF++ Scores by Language')
plt.axhline(y=avg, color='r', linestyle='--', label='Average ChrF++')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
plt.show()
